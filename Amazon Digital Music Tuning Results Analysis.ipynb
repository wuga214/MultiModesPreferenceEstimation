# %%
import ast
import os
import pandas as pd
pd.set_option('display.max_columns', 30)

# %%
def load_tuning_results(folder_path):
    csv_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.csv')]
    
    df = pd.DataFrame()
    for record in csv_files:
        df = df.append(pd.read_csv(record))
    return df

# %%
df_tuning_results = load_tuning_results(folder_path='tables/amazon/digital_music/tuning_general/')
df_tuning_results = df_tuning_results.drop_duplicates()
df_tuning_results.drop(['similarity', 'batch_size', 'normalize', 'topK'], inplace=True, axis=1)

# %%
def sort_tuning_results(df, metric):
    df[metric+'_Score'] = df[metric].map(lambda x: ast.literal_eval(x)[0])
    df = df.sort_values(by=metric+'_Score', ascending=False)
    return df

# %% [markdown]
# # Alpha

# %%
print(df_tuning_results['alpha'].unique())
print("{}: {}".format(0, len(df_tuning_results[df_tuning_results['alpha']==0])))
print("{}: {}".format(0.1, len(df_tuning_results[df_tuning_results['alpha']==0.1])))
print("{}: {}".format(1, len(df_tuning_results[df_tuning_results['alpha']==1])))
# Out:
# [0.  0.1 1. ]
# 0: 435
# 0.1: 343
# 1: 341

# %% [markdown]
# # Drop Out Rate

# %%
print(df_tuning_results['corruption'].unique())
print("{}: {}".format(0.2, len(df_tuning_results[df_tuning_results['corruption']==0.2])))
print("{}: {}".format(0.3, len(df_tuning_results[df_tuning_results['corruption']==0.3])))
print("{}: {}".format(0.4, len(df_tuning_results[df_tuning_results['corruption']==0.4])))
# Out:
# [0.2 0.3 0.4]
# 0.2: 408
# 0.3: 343
# 0.4: 368

# %% [markdown]
# # Key Dimension

# %%
print(df_tuning_results['key_dimension'].unique())
print("{}: {}".format(3, len(df_tuning_results[df_tuning_results['key_dimension']==3])))
print("{}: {}".format(4, len(df_tuning_results[df_tuning_results['key_dimension']==4])))
print("{}: {}".format(5, len(df_tuning_results[df_tuning_results['key_dimension']==5])))
# Out:
# [4 5 3]
# 3: 993
# 4: 89
# 5: 37

# %% [markdown]
# # Lambda

# %%
print(df_tuning_results['lambda'].unique())
print("{}: {}".format(1e-2, len(df_tuning_results[df_tuning_results['lambda']==1e-2])))
print("{}: {}".format(1e-3, len(df_tuning_results[df_tuning_results['lambda']==1e-3])))
print("{}: {}".format(1e-4, len(df_tuning_results[df_tuning_results['lambda']==1e-4])))
print("{}: {}".format(1e-5, len(df_tuning_results[df_tuning_results['lambda']==1e-5])))
print("{}: {}".format(1e-6, len(df_tuning_results[df_tuning_results['lambda']==1e-6])))
# Out:
# [1.e-03 1.e-04 1.e-05 1.e-06 1.e-02]
# 0.01: 9
# 0.001: 295
# 0.0001: 266
# 1e-05: 303
# 1e-06: 246

# %% [markdown]
# # Learning Rate

# %%
print(df_tuning_results['learning_rate'].unique())
print("{}: {}".format(1e-5, len(df_tuning_results[df_tuning_results['learning_rate']==1e-5])))
print("{}: {}".format(5e-5, len(df_tuning_results[df_tuning_results['learning_rate']==5e-5])))
print("{}: {}".format(1e-4, len(df_tuning_results[df_tuning_results['learning_rate']==1e-4])))
print("{}: {}".format(5e-4, len(df_tuning_results[df_tuning_results['learning_rate']==5e-4])))
# Out:
# [5.e-05 1.e-04 5.e-04 1.e-05]
# 1e-05: 26
# 5e-05: 406
# 0.0001: 348
# 0.0005: 339

# %% [markdown]
# # Mode Dimension

# %%
print(df_tuning_results['mode_dimension'].unique())
print("{}: {}".format(1, len(df_tuning_results[df_tuning_results['mode_dimension']==1])))
print("{}: {}".format(3, len(df_tuning_results[df_tuning_results['mode_dimension']==3])))
print("{}: {}".format(5, len(df_tuning_results[df_tuning_results['mode_dimension']==5])))
# Out:
# [3 5 1]
# 1: 408
# 3: 356
# 5: 355

# %% [markdown]
# # Rank

# %%
print(df_tuning_results['rank'].unique())
print("{}: {}".format(40, len(df_tuning_results[df_tuning_results['rank']==40])))
print("{}: {}".format(60, len(df_tuning_results[df_tuning_results['rank']==60])))
print("{}: {}".format(80, len(df_tuning_results[df_tuning_results['rank']==80])))
print("{}: {}".format(100, len(df_tuning_results[df_tuning_results['rank']==100])))
print("{}: {}".format(150, len(df_tuning_results[df_tuning_results['rank']==150])))
print("{}: {}".format(200, len(df_tuning_results[df_tuning_results['rank']==200])))
# Out:
# [ 40  80  60 100 150 200]
# 40: 26
# 60: 370
# 80: 360
# 100: 346
# 150: 9
# 200: 8

# %%
sort_tuning_results(df=df_tuning_results, metric='NDCG')
# Out:
#      model  alpha  corruption  epoch  iteration  key_dimension   lambda  \
# 1095   MMP    0.0         0.4    300         10              3  0.00100
# 1107   MMP    0.0         0.4    300         10              4  0.01000
# 1110   MMP    0.0         0.4    300         10              4  0.00010
# 1098   MMP    0.0         0.4    300         10              3  0.01000
# 1113   MMP    0.0         0.4    300         10              5  0.00100
# ...    ...    ...         ...    ...        ...            ...      ...
# 827    MMP    1.0         0.2    300         10              3  0.00010
# 826    MMP    0.1         0.4    300         10              3  0.00010
# 825    MMP    0.1         0.3    300         10              3  0.00010
# 824    MMP    0.1         0.2    300         10              3  0.00010
# 559    MMP    0.0         0.2    300         10              3  0.00001
#
#       learning_rate  mode_dimension  rank  root              NDCG  \
# 1095        0.00001               5   200   1.0  [0.0536, 0.0024]
# 1107        0.00001               5   200   1.0  [0.0536, 0.0024]
# 1110        0.00001               5   200   1.0  [0.0536, 0.0024]
# 1098        0.00001               5   200   1.0  [0.0533, 0.0024]
# 1113        0.00001               5   200   1.0  [0.0532, 0.0024]
# ...             ...             ...   ...   ...               ...
# 827         0.00050               5    80   1.0  [0.0015, 0.0003]
# 826         0.00050               5    80   1.0  [0.0015, 0.0003]
# 825         0.00050               5    80   1.0  [0.0015, 0.0003]
# 824         0.00050               5    80   1.0  [0.0015, 0.0003]
# 559         0.00050               3    80   1.0  [0.0015, 0.0003]
#
#           Precision@10      Precision@15      Precision@20       Precision@5  \
# 1095  [0.0095, 0.0005]  [0.0078, 0.0004]  [0.0068, 0.0003]  [0.0137, 0.0008]
# 1107  [0.0096, 0.0005]  [0.0079, 0.0004]  [0.0069, 0.0003]  [0.0134, 0.0008]
# 1110  [0.0096, 0.0005]  [0.0078, 0.0004]  [0.0069, 0.0003]  [0.0134, 0.0008]
# 1098  [0.0094, 0.0005]  [0.0078, 0.0004]  [0.0068, 0.0003]  [0.0134, 0.0008]
# 1113  [0.0095, 0.0005]  [0.0077, 0.0004]  [0.0068, 0.0003]  [0.0133, 0.0008]
# ...                ...               ...               ...               ...
# 827   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 826   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 825   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 824   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 559   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
#
#           Precision@50       R-Precision         Recall@10         Recall@15  \
# 1095  [0.0042, 0.0002]  [0.0214, 0.0019]  [0.0561, 0.0031]  [0.0682, 0.0034]
# 1107  [0.0042, 0.0002]  [0.0215, 0.0019]  [0.0561, 0.0031]  [0.0686, 0.0034]
# 1110  [0.0042, 0.0002]  [0.0214, 0.0019]  [0.0567, 0.0031]   [0.068, 0.0034]
# 1098  [0.0041, 0.0002]  [0.0212, 0.0019]  [0.0547, 0.0031]  [0.0675, 0.0034]
# 1113  [0.0041, 0.0002]  [0.0213, 0.0019]  [0.0559, 0.0031]   [0.068, 0.0034]
# ...                ...               ...               ...               ...
# 827      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 826      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 825      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 824      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 559      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
#
#              Recall@20          Recall@5         Recall@50  NDCG_Score
# 1095  [0.0782, 0.0037]  [0.0406, 0.0027]  [0.1175, 0.0044]      0.0536
# 1107  [0.0793, 0.0037]  [0.0399, 0.0026]  [0.1182, 0.0044]      0.0536
# 1110  [0.0795, 0.0037]  [0.0402, 0.0027]  [0.1175, 0.0044]      0.0536
# 1098  [0.0778, 0.0036]  [0.0401, 0.0027]  [0.1165, 0.0044]      0.0533
# 1113  [0.0785, 0.0037]  [0.0398, 0.0026]  [0.1159, 0.0043]      0.0532
# ...                ...               ...               ...         ...
# 827   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 826   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 825   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 824   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 559   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
#
# [1119 rows x 24 columns]

# %%
sort_tuning_results(df=df_tuning_results, metric='Precision@10')
# Out:
#      model  alpha  corruption  epoch  iteration  key_dimension   lambda  \
# 1107   MMP    0.0         0.4    300         10              4  0.01000
# 1110   MMP    0.0         0.4    300         10              4  0.00010
# 1113   MMP    0.0         0.4    300         10              5  0.00100
# 1101   MMP    0.0         0.4    300         10              3  0.00010
# 1095   MMP    0.0         0.4    300         10              3  0.00100
# ...    ...    ...         ...    ...        ...            ...      ...
# 425    MMP    0.1         0.3    300         10              3  0.00001
# 847    MMP    0.0         0.2    300         10              3  0.00001
# 439    MMP    0.0         0.2    300         10              3  0.00010
# 444    MMP    0.1         0.4    300         10              3  0.00010
# 559    MMP    0.0         0.2    300         10              3  0.00001
#
#       learning_rate  mode_dimension  rank  root              NDCG  \
# 1107        0.00001               5   200   1.0  [0.0536, 0.0024]
# 1110        0.00001               5   200   1.0  [0.0536, 0.0024]
# 1113        0.00001               5   200   1.0  [0.0532, 0.0024]
# 1101        0.00001               5   200   1.0  [0.0532, 0.0023]
# 1095        0.00001               5   200   1.0  [0.0536, 0.0024]
# ...             ...             ...   ...   ...               ...
# 425         0.00005               3    60   1.0  [0.0015, 0.0003]
# 847         0.00005               5    60   1.0  [0.0015, 0.0003]
# 439         0.00010               3    80   1.0  [0.0015, 0.0003]
# 444         0.00010               3    80   1.0  [0.0015, 0.0003]
# 559         0.00050               3    80   1.0  [0.0015, 0.0003]
#
#           Precision@10      Precision@15      Precision@20       Precision@5  \
# 1107  [0.0096, 0.0005]  [0.0079, 0.0004]  [0.0069, 0.0003]  [0.0134, 0.0008]
# 1110  [0.0096, 0.0005]  [0.0078, 0.0004]  [0.0069, 0.0003]  [0.0134, 0.0008]
# 1113  [0.0095, 0.0005]  [0.0077, 0.0004]  [0.0068, 0.0003]  [0.0133, 0.0008]
# 1101  [0.0095, 0.0005]  [0.0077, 0.0004]  [0.0067, 0.0003]  [0.0132, 0.0008]
# 1095  [0.0095, 0.0005]  [0.0078, 0.0004]  [0.0068, 0.0003]  [0.0137, 0.0008]
# ...                ...               ...               ...               ...
# 425   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 847   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 439   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 444   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 559   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
#
#           Precision@50       R-Precision         Recall@10         Recall@15  \
# 1107  [0.0042, 0.0002]  [0.0215, 0.0019]  [0.0561, 0.0031]  [0.0686, 0.0034]
# 1110  [0.0042, 0.0002]  [0.0214, 0.0019]  [0.0567, 0.0031]   [0.068, 0.0034]
# 1113  [0.0041, 0.0002]  [0.0213, 0.0019]  [0.0559, 0.0031]   [0.068, 0.0034]
# 1101  [0.0041, 0.0002]  [0.0212, 0.0019]  [0.0561, 0.0031]  [0.0671, 0.0034]
# 1095  [0.0042, 0.0002]  [0.0214, 0.0019]  [0.0561, 0.0031]  [0.0682, 0.0034]
# ...                ...               ...               ...               ...
# 425      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 847      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 439      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 444      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 559      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
#
#              Recall@20          Recall@5         Recall@50  NDCG_Score  \
# 1107  [0.0793, 0.0037]  [0.0399, 0.0026]  [0.1182, 0.0044]      0.0536
# 1110  [0.0795, 0.0037]  [0.0402, 0.0027]  [0.1175, 0.0044]      0.0536
# 1113  [0.0785, 0.0037]  [0.0398, 0.0026]  [0.1159, 0.0043]      0.0532
# 1101  [0.0774, 0.0036]  [0.0398, 0.0027]  [0.1165, 0.0044]      0.0532
# 1095  [0.0782, 0.0037]  [0.0406, 0.0027]  [0.1175, 0.0044]      0.0536
# ...                ...               ...               ...         ...
# 425   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 847   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 439   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 444   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 559   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
#
#       Precision@10_Score
# 1107              0.0096
# 1110              0.0096
# 1113              0.0095
# 1101              0.0095
# 1095              0.0095
# ...                  ...
# 425               0.0002
# 847               0.0002
# 439               0.0002
# 444               0.0002
# 559               0.0002
#
# [1119 rows x 25 columns]

# %%
sort_tuning_results(df=df_tuning_results, metric='R-Precision')
# Out:
#      model  alpha  corruption  epoch  iteration  key_dimension   lambda  \
# 1104   MMP    0.0         0.4    300         10              4  0.00100
# 1107   MMP    0.0         0.4    300         10              4  0.01000
# 1095   MMP    0.0         0.4    300         10              3  0.00100
# 1110   MMP    0.0         0.4    300         10              4  0.00010
# 1116   MMP    0.0         0.4    300         10              5  0.01000
# ...    ...    ...         ...    ...        ...            ...      ...
# 877    MMP    0.1         0.2    300         10              3  0.00001
# 876    MMP    0.0         0.4    300         10              3  0.00001
# 875    MMP    0.0         0.3    300         10              3  0.00001
# 874    MMP    0.0         0.2    300         10              3  0.00001
# 559    MMP    0.0         0.2    300         10              3  0.00001
#
#       learning_rate  mode_dimension  rank  root              NDCG  \
# 1104        0.00001               5   200   1.0  [0.0532, 0.0024]
# 1107        0.00001               5   200   1.0  [0.0536, 0.0024]
# 1095        0.00001               5   200   1.0  [0.0536, 0.0024]
# 1110        0.00001               5   200   1.0  [0.0536, 0.0024]
# 1116        0.00001               5   200   1.0  [0.0531, 0.0023]
# ...             ...             ...   ...   ...               ...
# 877         0.00050               5   100   1.0  [0.0015, 0.0003]
# 876         0.00050               5   100   1.0  [0.0015, 0.0003]
# 875         0.00050               5   100   1.0  [0.0015, 0.0003]
# 874         0.00050               5   100   1.0  [0.0015, 0.0003]
# 559         0.00050               3    80   1.0  [0.0015, 0.0003]
#
#           Precision@10      Precision@15      Precision@20       Precision@5  \
# 1104  [0.0093, 0.0005]  [0.0077, 0.0004]  [0.0067, 0.0003]  [0.0132, 0.0008]
# 1107  [0.0096, 0.0005]  [0.0079, 0.0004]  [0.0069, 0.0003]  [0.0134, 0.0008]
# 1095  [0.0095, 0.0005]  [0.0078, 0.0004]  [0.0068, 0.0003]  [0.0137, 0.0008]
# 1110  [0.0096, 0.0005]  [0.0078, 0.0004]  [0.0069, 0.0003]  [0.0134, 0.0008]
# 1116  [0.0094, 0.0005]  [0.0078, 0.0004]  [0.0067, 0.0003]  [0.0135, 0.0008]
# ...                ...               ...               ...               ...
# 877   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 876   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 875   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 874   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 559   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
#
#           Precision@50       R-Precision         Recall@10         Recall@15  \
# 1104  [0.0042, 0.0002]  [0.0215, 0.0019]  [0.0541, 0.0031]  [0.0674, 0.0034]
# 1107  [0.0042, 0.0002]  [0.0215, 0.0019]  [0.0561, 0.0031]  [0.0686, 0.0034]
# 1095  [0.0042, 0.0002]  [0.0214, 0.0019]  [0.0561, 0.0031]  [0.0682, 0.0034]
# 1110  [0.0042, 0.0002]  [0.0214, 0.0019]  [0.0567, 0.0031]   [0.068, 0.0034]
# 1116  [0.0041, 0.0002]  [0.0213, 0.0019]  [0.0555, 0.0031]  [0.0676, 0.0034]
# ...                ...               ...               ...               ...
# 877      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 876      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 875      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 874      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 559      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
#
#              Recall@20          Recall@5         Recall@50  NDCG_Score  \
# 1104  [0.0776, 0.0036]  [0.0396, 0.0026]  [0.1171, 0.0044]      0.0532
# 1107  [0.0793, 0.0037]  [0.0399, 0.0026]  [0.1182, 0.0044]      0.0536
# 1095  [0.0782, 0.0037]  [0.0406, 0.0027]  [0.1175, 0.0044]      0.0536
# 1110  [0.0795, 0.0037]  [0.0402, 0.0027]  [0.1175, 0.0044]      0.0536
# 1116  [0.0777, 0.0036]  [0.0402, 0.0027]  [0.1159, 0.0043]      0.0531
# ...                ...               ...               ...         ...
# 877   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 876   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 875   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 874   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 559   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
#
#       Precision@10_Score  R-Precision_Score
# 1104              0.0093             0.0215
# 1107              0.0096             0.0215
# 1095              0.0095             0.0214
# 1110              0.0096             0.0214
# 1116              0.0094             0.0213
# ...                  ...                ...
# 877               0.0002             0.0002
# 876               0.0002             0.0002
# 875               0.0002             0.0002
# 874               0.0002             0.0002
# 559               0.0002             0.0002
#
# [1119 rows x 26 columns]

# %%
sort_tuning_results(df=df_tuning_results, metric='Recall@10')
# Out:
#      model  alpha  corruption  epoch  iteration  key_dimension    lambda  \
# 1110   MMP    0.0         0.4    300         10              4  0.000100
# 1095   MMP    0.0         0.4    300         10              3  0.001000
# 1101   MMP    0.0         0.4    300         10              3  0.000100
# 1107   MMP    0.0         0.4    300         10              4  0.010000
# 1113   MMP    0.0         0.4    300         10              5  0.001000
# ...    ...    ...         ...    ...        ...            ...       ...
# 391    MMP    0.1         0.4    300         10              3  0.000001
# 831    MMP    0.0         0.3    300         10              3  0.000100
# 830    MMP    0.0         0.2    300         10              3  0.000100
# 829    MMP    1.0         0.4    300         10              3  0.000100
# 559    MMP    0.0         0.2    300         10              3  0.000010
#
#       learning_rate  mode_dimension  rank  root              NDCG  \
# 1110        0.00001               5   200   1.0  [0.0536, 0.0024]
# 1095        0.00001               5   200   1.0  [0.0536, 0.0024]
# 1101        0.00001               5   200   1.0  [0.0532, 0.0023]
# 1107        0.00001               5   200   1.0  [0.0536, 0.0024]
# 1113        0.00001               5   200   1.0  [0.0532, 0.0024]
# ...             ...             ...   ...   ...               ...
# 391         0.00050               3    60   1.0  [0.0015, 0.0003]
# 831         0.00010               3    60   1.0  [0.0015, 0.0003]
# 830         0.00010               3    60   1.0  [0.0015, 0.0003]
# 829         0.00050               5    80   1.0  [0.0015, 0.0003]
# 559         0.00050               3    80   1.0  [0.0015, 0.0003]
#
#           Precision@10      Precision@15      Precision@20       Precision@5  \
# 1110  [0.0096, 0.0005]  [0.0078, 0.0004]  [0.0069, 0.0003]  [0.0134, 0.0008]
# 1095  [0.0095, 0.0005]  [0.0078, 0.0004]  [0.0068, 0.0003]  [0.0137, 0.0008]
# 1101  [0.0095, 0.0005]  [0.0077, 0.0004]  [0.0067, 0.0003]  [0.0132, 0.0008]
# 1107  [0.0096, 0.0005]  [0.0079, 0.0004]  [0.0069, 0.0003]  [0.0134, 0.0008]
# 1113  [0.0095, 0.0005]  [0.0077, 0.0004]  [0.0068, 0.0003]  [0.0133, 0.0008]
# ...                ...               ...               ...               ...
# 391   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 831   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 830   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 829   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
# 559   [0.0002, 0.0001]  [0.0002, 0.0001]     [0.0002, 0.0]  [0.0002, 0.0001]
#
#           Precision@50       R-Precision         Recall@10         Recall@15  \
# 1110  [0.0042, 0.0002]  [0.0214, 0.0019]  [0.0567, 0.0031]   [0.068, 0.0034]
# 1095  [0.0042, 0.0002]  [0.0214, 0.0019]  [0.0561, 0.0031]  [0.0682, 0.0034]
# 1101  [0.0041, 0.0002]  [0.0212, 0.0019]  [0.0561, 0.0031]  [0.0671, 0.0034]
# 1107  [0.0042, 0.0002]  [0.0215, 0.0019]  [0.0561, 0.0031]  [0.0686, 0.0034]
# 1113  [0.0041, 0.0002]  [0.0213, 0.0019]  [0.0559, 0.0031]   [0.068, 0.0034]
# ...                ...               ...               ...               ...
# 391      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 831      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 830      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 829      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
# 559      [0.0002, 0.0]  [0.0002, 0.0002]   [0.001, 0.0004]  [0.0015, 0.0005]
#
#              Recall@20          Recall@5         Recall@50  NDCG_Score  \
# 1110  [0.0795, 0.0037]  [0.0402, 0.0027]  [0.1175, 0.0044]      0.0536
# 1095  [0.0782, 0.0037]  [0.0406, 0.0027]  [0.1175, 0.0044]      0.0536
# 1101  [0.0774, 0.0036]  [0.0398, 0.0027]  [0.1165, 0.0044]      0.0532
# 1107  [0.0793, 0.0037]  [0.0399, 0.0026]  [0.1182, 0.0044]      0.0536
# 1113  [0.0785, 0.0037]  [0.0398, 0.0026]  [0.1159, 0.0043]      0.0532
# ...                ...               ...               ...         ...
# 391   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 831   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 830   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 829   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
# 559   [0.0018, 0.0005]  [0.0005, 0.0003]  [0.0052, 0.0009]      0.0015
#
#       Precision@10_Score  R-Precision_Score  Recall@10_Score
# 1110              0.0096             0.0214           0.0567
# 1095              0.0095             0.0214           0.0561
# 1101              0.0095             0.0212           0.0561
# 1107              0.0096             0.0215           0.0561
# 1113              0.0095             0.0213           0.0559
# ...                  ...                ...              ...
# 391               0.0002             0.0002           0.0010
# 831               0.0002             0.0002           0.0010
# 830               0.0002             0.0002           0.0010
# 829               0.0002             0.0002           0.0010
# 559               0.0002             0.0002           0.0010
#
# [1119 rows x 27 columns]

# %%
# metric = 'NDCG'
# df_tuning_results[metric+'_Score'] = df_tuning_results[metric].map(lambda x: ast.literal_eval(x)[0])
# df_tuning_results.sort_values(by=metric+'_Score', ascending=False)
