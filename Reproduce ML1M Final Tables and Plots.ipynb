# %%
from os import listdir
from os.path import isfile, join

import ast
import os
import pandas as pd

# %%
DATASET_NAME = 'ml1m'

# %%
df_baseline = pd.read_csv("tables/ml1m/movielens1m_result.csv", index_col=None, header=0)

# %%
df_baseline = df_baseline[['model', 'R-Precision', 'NDCG', 'MAP@5',  'MAP@10', 'MAP@20', 'Precision@5', 'Precision@10', 'Precision@20', 'Recall@5', 'Recall@10', 'Recall@20']]

# %%
remaining_metrics = ['R-Precision', 'NDCG', 'MAP@5',  'MAP@10', 'MAP@20', 'Precision@5', 'Precision@10', 'Precision@20', 'Recall@5', 'Recall@10', 'Recall@20']

# %%
for metric in remaining_metrics:
    df_baseline[metric] = df_baseline[metric].map(lambda x: ast.literal_eval(x)[0])

# %%
df_baseline = df_baseline.sort_values(by='model')

# %%
df_baseline
# Out:
#         model  R-Precision    NDCG   MAP@5  MAP@10  MAP@20  Precision@5  \
# 10    AutoRec       0.0945  0.1674  0.1254  0.1202  0.1131       0.1194
# 2         BPR       0.0933  0.1675  0.1192  0.1153  0.1102       0.1141
# 7        CDAE       0.0941  0.1588  0.1297  0.1234  0.1155       0.1226
# 5         CML       0.1000  0.1767  0.1356  0.1299  0.1229       0.1297
# 4   NCE-PLRec       0.0991  0.1790  0.1310  0.1250  0.1181       0.1248
# 3     NCE-SVD       0.0756  0.1409  0.0966  0.0930  0.0882       0.0927
# 1       PLRec       0.0953  0.1704  0.1248  0.1198  0.1132       0.1197
# 0         POP       0.0736  0.1225  0.1168  0.1099  0.1031       0.1085
# 6     PureSVD       0.0920  0.1644  0.1212  0.1161  0.1098       0.1160
# 9      VAE-CF       0.0892  0.1634  0.1066  0.1045  0.1006       0.1054
# 8        WRMF       0.0970  0.1788  0.1235  0.1193  0.1140       0.1198
#
#     Precision@10  Precision@20  Recall@5  Recall@10  Recall@20
# 10        0.1115        0.1029    0.0377     0.0690     0.1215
# 2         0.1094        0.1016    0.0375     0.0692     0.1228
# 7         0.1143        0.1035    0.0350     0.0618     0.1079
# 5         0.1221        0.1114    0.0400     0.0718     0.1265
# 4         0.1170        0.1071    0.0424     0.0775     0.1358
# 3         0.0872        0.0803    0.0344     0.0619     0.1096
# 1         0.1116        0.1032    0.0401     0.0719     0.1279
# 0         0.0999        0.0934    0.0237     0.0434     0.0841
# 6         0.1079        0.0998    0.0383     0.0693     0.1230
# 9         0.1008        0.0942    0.0376     0.0688     0.1207
# 8         0.1129        0.1053    0.0411     0.0749     0.1344

# %% [markdown]
# # Final Recommendation Performance

# %%
folder_path = 'tables/ml1m/dvae/final_general/'
    
csv_files = [join(folder_path, f) for f in listdir(folder_path) 
             if isfile(join(folder_path, f)) and f.endswith('.csv')]
print(csv_files)
# Out:
# ['tables/amazon/digital_music/dvae/final_general/final.csv']

# %%
df_list = []

for filename in csv_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df_list.append(df)

df = pd.concat(df_list, axis=0, ignore_index=True)

# %%
df.insert(0, 'model', 'MacridVAE')

# %%
df
# Out:
#        model    lam      lr  kfac  dfac  beta            MAP@10  \
# 0  MacridVAE  0.001  0.0001     5   200   0.2  [0.0305, 0.0013]
#
#             MAP@15            MAP@20             MAP@5  ...      Precision@15  \
# 0  [0.0257, 0.001]  [0.0226, 0.0009]  [0.0396, 0.0019]  ...  [0.0147, 0.0005]
#
#        Precision@20       Precision@5      Precision@50       R-Precision  \
# 0  [0.0125, 0.0004]  [0.0277, 0.0012]  [0.0074, 0.0002]  [0.0495, 0.0029]
#
#           Recall@10         Recall@15         Recall@20          Recall@5  \
# 0  [0.1047, 0.0042]  [0.1209, 0.0044]  [0.1351, 0.0047]  [0.0815, 0.0038]
#
#           Recall@50
# 0  [0.1915, 0.0054]
#
# [1 rows x 23 columns]

# %%
remaining_metrics = ['R-Precision', 'NDCG', 'MAP@5',  'MAP@10', 'MAP@20', 'Precision@5', 'Precision@10', 'Precision@20', 'Recall@5', 'Recall@10', 'Recall@20']

# %%
for metric in remaining_metrics:
    df[metric] = df[metric].map(lambda x: ast.literal_eval(x)[0])

# %%
df
# Out:
#        model    lam      lr  kfac  dfac  beta  MAP@10           MAP@15  \
# 0  MacridVAE  0.001  0.0001     5   200   0.2  0.0305  [0.0257, 0.001]
#
#    MAP@20   MAP@5  ...      Precision@15  Precision@20  Precision@5  \
# 0  0.0226  0.0396  ...  [0.0147, 0.0005]        0.0125       0.0277
#
#        Precision@50  R-Precision  Recall@10         Recall@15  Recall@20  \
# 0  [0.0074, 0.0002]       0.0495     0.1047  [0.1209, 0.0044]     0.1351
#
#    Recall@5         Recall@50
# 0    0.0815  [0.1915, 0.0054]
#
# [1 rows x 23 columns]

# %%
df = df.sort_values(by='NDCG', ascending=False)[['model', 'R-Precision', 'NDCG', 'MAP@5',  'MAP@10', 'MAP@20', 'Precision@5', 'Precision@10', 'Precision@20', 'Recall@5', 'Recall@10', 'Recall@20']]
df
# Out:
#        model  R-Precision    NDCG   MAP@5  MAP@10  MAP@20  Precision@5  \
# 0  MacridVAE       0.0495  0.0997  0.0396  0.0305  0.0226       0.0277
#
#    Precision@10  Precision@20  Recall@5  Recall@10  Recall@20
# 0        0.0186        0.0125    0.0815     0.1047     0.1351

# %%
df_total = df_baseline.append(df)
df_total
# Out:
#         model  R-Precision    NDCG   MAP@5  MAP@10  MAP@20  Precision@5  \
# 10    AutoRec       0.0945  0.1674  0.1254  0.1202  0.1131       0.1194
# 2         BPR       0.0933  0.1675  0.1192  0.1153  0.1102       0.1141
# 7        CDAE       0.0941  0.1588  0.1297  0.1234  0.1155       0.1226
# 5         CML       0.1000  0.1767  0.1356  0.1299  0.1229       0.1297
# 4   NCE-PLRec       0.0991  0.1790  0.1310  0.1250  0.1181       0.1248
# 3     NCE-SVD       0.0756  0.1409  0.0966  0.0930  0.0882       0.0927
# 1       PLRec       0.0953  0.1704  0.1248  0.1198  0.1132       0.1197
# 0         POP       0.0736  0.1225  0.1168  0.1099  0.1031       0.1085
# 6     PureSVD       0.0920  0.1644  0.1212  0.1161  0.1098       0.1160
# 9      VAE-CF       0.0892  0.1634  0.1066  0.1045  0.1006       0.1054
# 8        WRMF       0.0970  0.1788  0.1235  0.1193  0.1140       0.1198
# 0   MacridVAE       0.0495  0.0997  0.0396  0.0305  0.0226       0.0277
#
#     Precision@10  Precision@20  Recall@5  Recall@10  Recall@20
# 10        0.1115        0.1029    0.0377     0.0690     0.1215
# 2         0.1094        0.1016    0.0375     0.0692     0.1228
# 7         0.1143        0.1035    0.0350     0.0618     0.1079
# 5         0.1221        0.1114    0.0400     0.0718     0.1265
# 4         0.1170        0.1071    0.0424     0.0775     0.1358
# 3         0.0872        0.0803    0.0344     0.0619     0.1096
# 1         0.1116        0.1032    0.0401     0.0719     0.1279
# 0         0.0999        0.0934    0.0237     0.0434     0.0841
# 6         0.1079        0.0998    0.0383     0.0693     0.1230
# 9         0.1008        0.0942    0.0376     0.0688     0.1207
# 8         0.1129        0.1053    0.0411     0.0749     0.1344
# 0         0.0186        0.0125    0.0815     0.1047     0.1351

# %%
df_total.to_csv('tables/ml1m/results.csv', index=False)
